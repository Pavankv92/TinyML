# %% [markdown]
# # Create a CNN to classify Cifar-10
#
# Learn about Cifar-10 here: https://www.cs.toronto.edu/~kriz/cifar.html
#
# In class you saw how to build a Convolutional Neural Network that classified Fashion MNIST. Take what you learned to build a CNN that recognizes the 10 classes of CIFAR. It will be a similar network, but there are some key differences you'll need to take into account.
#
# First, while MNIST were 28x28 monochome images (1 color channel), CIFAR are 32x32 color images (3 color channels).
#
# Second, MNIST images are simple, containing just the object, centered in the image, with no background. CIFAR ones can have the object with a background -- for example airplanes might have a cloudy sky behind them! As such you should expect your accuracy to be a bit lower.
#
# We start by setting up the problem for you.

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images = train_images / 255.0
test_images = test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# We then definte some of the model for you but leave most of it for you to fill in!
#
# *A hint: your model may want to learn some high level features and then classify them.*

# %%
FIRST_LAYER = tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(32,32,3))
HIDDEN_LAYER_TYPE_1 = tf.keras.layers.MaxPooling2D(2,2)
HIDDEN_LAYER_TYPE_2 = tf.keras.layers.Conv2D(64, (3,3), activation='relu')
HIDDEN_LAYER_TYPE_3 = tf.keras.layers.MaxPooling2D(2,2)
HIDDEN_LAYER_TYPE_4 = tf.keras.layers.Conv2D(64, (3,3), activation='relu')
HIDDEN_LAYER_TYPE_5 = tf.keras.layers.Dense(20, activation='relu')
LAST_LAYER = tf.keras.layers.Dense(10, activation='softmax')

model = models.Sequential([
       FIRST_LAYER,
       HIDDEN_LAYER_TYPE_1,
       HIDDEN_LAYER_TYPE_2,
       HIDDEN_LAYER_TYPE_3,
       HIDDEN_LAYER_TYPE_4,
       layers.Flatten(),
       HIDDEN_LAYER_TYPE_5,
       LAST_LAYER,
])

# %% [markdown]
# You then need to define loss function. And you can then train your model. Once training is done you'll see a plot of training and validation accuracy. You'll know you have a reasonable model with a reasonable loss funciton if your final training accuracy ends up in the 70s (or possibly higher).
#
# *A hint: your model may want to learn different categories.*

# %%
LOSS = 'sparse_categorical_crossentropy'#YOUR CODE HERE#
NUM_EPOCHS = 20 #You can change this value if you like to experiment with it to get better accuracy

# Compile the model
model.compile(optimizer='sgd',
              loss=LOSS,
              metrics=['accuracy'])

# Fit the model
history = model.fit(train_images, train_labels, epochs=NUM_EPOCHS,
                    validation_data=(test_images, test_labels))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xlim([0,NUM_EPOCHS])
plt.ylim([0.4,1.0])
plt.show()
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 9s 5ms/step - loss: 2.2057 - accuracy: 0.1679 - val_loss: 1.9856 - val_accuracy: 0.2642
# Epoch 2/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.8548 - accuracy: 0.3236 - val_loss: 2.0428 - val_accuracy: 0.3016
# Epoch 3/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.5716 - accuracy: 0.4312 - val_loss: 1.4877 - val_accuracy: 0.4619
# Epoch 4/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.4168 - accuracy: 0.4901 - val_loss: 1.4088 - val_accuracy: 0.4955
# Epoch 5/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3169 - accuracy: 0.5280 - val_loss: 1.2804 - val_accuracy: 0.5363
# Epoch 6/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.2328 - accuracy: 0.5612 - val_loss: 1.3143 - val_accuracy: 0.5193
# Epoch 7/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.1605 - accuracy: 0.5899 - val_loss: 1.4369 - val_accuracy: 0.5161
# Epoch 8/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0965 - accuracy: 0.6155 - val_loss: 1.1523 - val_accuracy: 0.5934
# Epoch 9/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0450 - accuracy: 0.6327 - val_loss: 1.1529 - val_accuracy: 0.5936
# Epoch 10/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.0011 - accuracy: 0.6499 - val_loss: 1.0348 - val_accuracy: 0.6410
# Epoch 11/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9587 - accuracy: 0.6662 - val_loss: 1.1110 - val_accuracy: 0.6072
# Epoch 12/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9216 - accuracy: 0.6793 - val_loss: 1.1182 - val_accuracy: 0.6278
# Epoch 13/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8877 - accuracy: 0.6908 - val_loss: 0.9675 - val_accuracy: 0.6710
# Epoch 14/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8573 - accuracy: 0.7004 - val_loss: 0.9642 - val_accuracy: 0.6649
# Epoch 15/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.8285 - accuracy: 0.7116 - val_loss: 0.9768 - val_accuracy: 0.6616
# Epoch 16/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7993 - accuracy: 0.7237 - val_loss: 1.0334 - val_accuracy: 0.6601
# Epoch 17/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7759 - accuracy: 0.7305 - val_loss: 0.9216 - val_accuracy: 0.6858
# Epoch 18/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7513 - accuracy: 0.7393 - val_loss: 0.9345 - val_accuracy: 0.6851
# Epoch 19/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7274 - accuracy: 0.7458 - val_loss: 0.9554 - val_accuracy: 0.6816
# Epoch 20/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7063 - accuracy: 0.7563 - val_loss: 0.9469 - val_accuracy: 0.6935

# %% [markdown]
# Finally, pick a better optimizer. And re-train your model. You'll know you have a reasonable model with a reasonable loss funciton and optimizer if your final training accuracy ends up in the 80s (or possibly higher).
#
# *A hint: your model may want to learn adaptively.*

# %%
OPTIMIZER = 'adam'#YOUR CODE HERE#

# Compile the model
model.compile(optimizer=OPTIMIZER,
              loss=LOSS,
              metrics=['accuracy'])

# Fit the model
history = model.fit(train_images, train_labels, epochs=NUM_EPOCHS,
                    validation_data=(test_images, test_labels))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xlim([0,NUM_EPOCHS])
plt.ylim([0.4,1.0])
plt.show()
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 11s 6ms/step - loss: 0.8512 - accuracy: 0.7024 - val_loss: 0.9599 - val_accuracy: 0.6741
# Epoch 2/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7796 - accuracy: 0.7286 - val_loss: 0.9767 - val_accuracy: 0.6731
# Epoch 3/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7096 - accuracy: 0.7525 - val_loss: 0.8827 - val_accuracy: 0.7005
# Epoch 4/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6428 - accuracy: 0.7758 - val_loss: 0.8593 - val_accuracy: 0.7140
# Epoch 5/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.5893 - accuracy: 0.7931 - val_loss: 0.8805 - val_accuracy: 0.7078
# Epoch 6/20
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.5420 - accuracy: 0.8108 - val_loss: 0.9162 - val_accuracy: 0.7158
# Epoch 7/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4988 - accuracy: 0.8237 - val_loss: 0.9343 - val_accuracy: 0.7137
# Epoch 8/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.4533 - accuracy: 0.8399 - val_loss: 1.0011 - val_accuracy: 0.7075
# Epoch 9/20
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.4212 - accuracy: 0.8492 - val_loss: 0.9907 - val_accuracy: 0.7214
# Epoch 10/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.3794 - accuracy: 0.8652 - val_loss: 1.0087 - val_accuracy: 0.7135
# Epoch 11/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.3544 - accuracy: 0.8749 - val_loss: 1.1460 - val_accuracy: 0.6971
# Epoch 12/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.3299 - accuracy: 0.8821 - val_loss: 1.1112 - val_accuracy: 0.7098
# Epoch 13/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.3038 - accuracy: 0.8923 - val_loss: 1.2266 - val_accuracy: 0.7044
# Epoch 14/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.2872 - accuracy: 0.8977 - val_loss: 1.2191 - val_accuracy: 0.7084
# Epoch 15/20
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.2662 - accuracy: 0.9057 - val_loss: 1.3024 - val_accuracy: 0.7058
# Epoch 16/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2451 - accuracy: 0.9109 - val_loss: 1.3573 - val_accuracy: 0.7042
# Epoch 17/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2279 - accuracy: 0.9187 - val_loss: 1.4062 - val_accuracy: 0.7019
# Epoch 18/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2253 - accuracy: 0.9190 - val_loss: 1.4463 - val_accuracy: 0.7003
# Epoch 19/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2170 - accuracy: 0.9232 - val_loss: 1.5108 - val_accuracy: 0.7042
# Epoch 20/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1956 - accuracy: 0.9294 - val_loss: 1.5041 - val_accuracy: 0.7019
